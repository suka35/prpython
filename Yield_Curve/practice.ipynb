# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install quandl

# %%
import pandas as pd
import quandl

# %%
QUANDL_KEY = '{41ardN13LAKMmDGz-id2}'
quandl.ApiConfig.api_key = QUANDL_KEY

# %%
df_quandl = quandl.get(dataset='WIKI/AAPL', start_date='2000-01-01', end_date='2010-12-31')
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# <ipython-input-18-68061faddab9> in <module>()
# ----> 1 df_quandl = quandl.get(dataset='WIKI/AAPL', start_date='2000-01-01', end_date='2010-12-31')
#
# /usr/local/lib/python3.6/dist-packages/quandl/get.py in get(dataset, **kwargs)
#      46         if dataset_args['column_index'] is not None:
#      47             kwargs.update({'column_index': dataset_args['column_index']})
# ---> 48         data = Dataset(dataset_args['code']).data(params=kwargs, handle_column_not_found=True)
#      49     # Array
#      50     elif isinstance(dataset, list):
#
# /usr/local/lib/python3.6/dist-packages/quandl/model/dataset.py in data(self, **options)
#      45         updated_options = Util.merge_options('params', params, **options)
#      46         try:
# ---> 47             return Data.all(**updated_options)
# ...
