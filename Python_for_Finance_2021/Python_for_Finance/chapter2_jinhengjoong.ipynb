# %% [markdown]
# 1판 (한국어) ch.3 입문용 예제

# %% [markdown]
# 구글 드라이브 불러오기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# BSM fomula

# %%
def bsm_call_value(S0, K, T, r, sigma): # 초기주가, 행사가격, 만기까지 남은 연도, 고정 무위험 단기 이자율, 변동성 파라미터
    S0 : float
    K : float
    T : float
    r : float
    sigma : float

    value : float

from math import log, sqrt, exp
from scipy import stats

S0 = float(S0)
d1 = (log(S0/K) + (r+0.5*sigma**2) * T / (sigma*sqrt(T)))
d2 = (log(S0/K) + (r-0.5*sigma**2) * T / (sigma*sqrt(T)))
value = (S0 * stats.norm.cdf(d1, 0.0, 1.0) - K * exp(-r * T) * stats.norm.cdf(d2, 0.0, 1.0))
return value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ef7cd1b8afee> in <module>()
#      11 from scipy import stats
#      12
# ---> 13 S0 = float(S0)
#      14 d1 = (log(S0/K) + (r+0.5*sigma**2) * T / (sigma*sqrt(T)))
#      15 d2 = (log(S0/K) + (r-0.5*sigma**2) * T / (sigma*sqrt(T)))
#
# NameError: name 'S0' is not defined

# %% [markdown]
# Introductory Examples

# %%
from pylab import plt
plt.style.use('seaborn')
import matplotlib as mpl
mpl.rcParams['font.family'] = 'serif'
import warnings; warnings.simplefilter('ignore')

# %% [markdown]
# 내재 변동성

# %%
V0 = 17.6639
r = 0.01

# %%
# !pip install h5py
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.19.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
import h5py
filename = "/content/drive/My Drive/Python_for_Finance/data/vstoxx_data_31032014.h5"
h5 = h5py.File(filename,'r')
futures_data = h5['futures_data']  # VSTOXX futures data
options_data = h5['options_data']  # VSTOXX call option data

# %%
import datetime as dt
import pandas as pd

# %%
futures_data
# Out:
# <HDF5 group "/futures_data" (8 members)>

# %%
options_data['IMP_VOL'] = 0.0 # 내재 변동성을 저장할 새로운 열
from bsm
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-38676b57da78> in <module>()
# ----> 1 options_data.info()
#
# AttributeError: 'Group' object has no attribute 'info'
