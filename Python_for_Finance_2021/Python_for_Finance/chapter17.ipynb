# %%
# 구글 드라이브 불러오기

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install get_year_deltas
# Out:
# ERROR: Could not find a version that satisfies the requirement get_year_deltas (from versions: none)
# ERROR: No matching distribution found for get_year_deltas

# %%
import numpy as np
import pandas as pd
import datetime as dt
from pylab import mpl, plt
import sys

# %% [markdown]
# ## Valuation Framework

# %% [markdown]
# ### Risk-Neutral Discounting

# %% [markdown]
# #### Modeling and Handling Dates

# %%
plt.style.use('seaborn')
mpl.rcParams['font.family'] = 'serif'
# %matplotlib inline

# %%
sys.path.append('../dx')

# %%
dates = [dt.datetime(2020, 1, 1), dt.datetime(2020, 7, 1), dt.datetime(2021, 1, 1)]

# %%
(dates[1] - dates[0]).days / 365.
# Out:
# 0.4986301369863014

# %%
(dates[2] - dates[1]).days / 365.
# Out:
# 0.5041095890410959

# %%
fractions = [0.0, 0.5, 1.0]

# %%
def get_year_deltas(date_list, day_count=365.):
    ''' Return vector of floats with day deltas in year fractions.
    Initial value normalized to zero.
    Parameters
    ==========
    date_list: list or array
    collection of datetime objects
    day_count: float
    number of days for a year
    (to account for different conventions)
    Results
    =======delta_list: array
        year fractions
    '''
    start = date_list[0]
    delta_list = [(date - start).days / day_count
                  for date in date_list]
    return np.array(delta_list)
