# %% [markdown]
# https://erickleppen.medium.com/a-look-at-linear-regression-with-examples-in-excel-and-python-d29c38fc87d6

# %%
import pandas as pd
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
#read training data csv file
train = pd.read_csv("C:/Users/sungh/Documents/GitHub/prpython/linearregression/trainek.csv")
print(train.shape)
train.head()
# Out:
# (1431, 12)
#    Unnamed: 0  SalePrice  LotArea  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# 0           0     208500     8450       1710             1             0
# 1           1     181500     9600       1262             0             1
# 2           2     223500    11250       1786             1             0
# 3           3     140000     9550       1717             1             0
# 4           4     250000    14260       2198             1             0
#
#    FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  Fireplaces  GarageCars
# 0         2         1             3             1           0           2
# 1         2         0             3             1           1           2
# 2         2         1             3             1           1           2
# 3         1         0             3             1           1           3
# 4         2         1             4             1           1           3

# %%
train.describe()
# Out:
#         Unnamed: 0      SalePrice       LotArea    GrLivArea  BsmtFullBath  \
# count  1431.000000    1431.000000   1431.000000  1431.000000   1431.000000
# mean    729.269741  178530.064291   9582.419287  1498.371069      0.415793
# std     422.081557   74843.635376   3732.704170   491.408955      0.512503
# min       0.000000   34900.000000   1300.000000   334.000000      0.000000
# 25%     363.500000  129500.000000   7500.000000  1125.500000      0.000000
# 50%     731.000000  161500.000000   9375.000000  1456.000000      0.000000
# 75%    1093.500000  212000.000000  11406.500000  1768.000000      1.000000
# max    1459.000000  611657.000000  25419.000000  3608.000000      3.000000
#
#        BsmtHalfBath     FullBath     HalfBath  BedroomAbvGr  KitchenAbvGr  \
# count   1431.000000  1431.000000  1431.000000   1431.000000   1431.000000
# mean       0.055905     1.558351     0.381551      2.860238      1.046820
# std        0.235826     0.542513     0.502910      0.811649      0.221032
# min        0.000000     0.000000     0.000000      0.000000      0.000000
# 25%        0.000000     1.000000     0.000000      2.000000      1.000000
# 50%        0.000000     2.000000     0.000000      3.000000      1.000000
# 75%        0.000000     2.000000     1.000000      3.000000      1.000000
# max        2.000000     3.000000     2.000000      8.000000      3.000000
#
#         Fireplaces   GarageCars
# count  1431.000000  1431.000000
# mean      0.596087     1.756115
# std       0.630539     0.746031
# min       0.000000     0.000000
# 25%       0.000000     1.000000
# 50%       1.000000     2.000000
# 75%       1.000000     2.000000
# max       3.000000     4.000000

# %%
px.histogram(train, x='SalePrice')

# %%
px.scatter(train, x='LotArea', y='SalePrice')

# %%
#perform simple linear regression
px.scatter(train, x='LotArea', y='SalePrice', trendline = 'ols', trendline_color_override="red")

# %%
px.scatter_matrix(train[['SalePrice', 'LotArea','GrLivArea']])

# %%
print(train.corr())
px.imshow(train.corr())
# Out:
#               Unnamed: 0  SalePrice   LotArea  GrLivArea  BsmtFullBath  \
# Unnamed: 0      1.000000  -0.024331 -0.003131  -0.001398      0.008911
# SalePrice      -0.024331   1.000000  0.394831   0.713183      0.219183
# LotArea        -0.003131   0.394831  1.000000   0.405992      0.086190
# GrLivArea      -0.001398   0.713183  0.405992   1.000000     -0.001996
# BsmtFullBath    0.008911   0.219183  0.086190  -0.001996      1.000000
# BsmtHalfBath   -0.021629  -0.037962  0.030296  -0.037423     -0.140388
# FullBath        0.001467   0.564193  0.191473   0.632150     -0.070973
# HalfBath        0.004008   0.282920  0.093501   0.421640     -0.035334
# BedroomAbvGr    0.030035   0.158591  0.270163   0.540710     -0.151034
# KitchenAbvGr    0.004617  -0.140782 -0.014078   0.109766     -0.042337
# Fireplaces     -0.016094   0.465582  0.312588   0.450545      0.106746
# GarageCars      0.015404   0.654589  0.280425   0.471325      0.119089
#
#               BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr  \
# Unnamed: 0       -0.021629  0.001467  0.004008      0.030035      0.004617
# SalePrice        -0.037962  0.564193  0.282920      0.158591     -0.140782
# LotArea           0.030296  0.191473  0.093501      0.270163     -0.014078
# GrLivArea        -0.037423  0.632150  0.421640      0.540710      0.109766
# BsmtFullBath     -0.140388 -0.070973 -0.035334     -0.151034     -0.042337
# BsmtHalfBath      1.000000 -0.069243 -0.014883      0.037196     -0.036835
# FullBath         -0.069243  1.000000  0.131078      0.348864      0.131742
# HalfBath         -0.014883  0.131078  1.000000      0.230099     -0.066458
# BedroomAbvGr      0.037196  0.348864  0.230099      1.000000      0.200216
# KitchenAbvGr     -0.036835  0.131742 -0.066458      0.200216      1.000000
# Fireplaces        0.029689  0.238623  0.208479      0.105511     -0.130146
# GarageCars       -0.025793  0.474915  0.214647      0.082254     -0.049447
#
#               Fireplaces  GarageCars
# Unnamed: 0     -0.016094    0.015404
# SalePrice       0.465582    0.654589
# LotArea         0.312588    0.280425
# GrLivArea       0.450545    0.471325
# BsmtFullBath    0.106746    0.119089
# BsmtHalfBath    0.029689   -0.025793
# FullBath        0.238623    0.474915
# HalfBath        0.208479    0.214647
# BedroomAbvGr    0.105511    0.082254
# KitchenAbvGr   -0.130146   -0.049447
# Fireplaces      1.000000    0.294399
# GarageCars      0.294399    1.000000

# %%
#create target variable
y = train['SalePrice']
#create array of features
x = train.drop(columns = 'SalePrice')
#split the data into train and test sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.55, random_state=42)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
#Predicting the prices
pred = model.predict(xtest)
#look at the top 5 predictions vs top 5 real
print(pred[:5])
ytest[:5]
# Out:
# [209087.34061326 136908.39742271 157336.41775501 156842.06519348
#   44816.15980075]
# 123     181000
# 1191    112000
# 462     148000
# 351     134000
# 1296     82500
# Name: SalePrice, dtype: int64

# %%
#appy mean absolute error
mean_absolute_error(y_true=ytest, y_pred=model.predict(xtest))
# Out:
# 26749.670558614504

# %%
#create target variable
y = train['SalePrice']
#create array of features
x = train.drop(columns = 'SalePrice')
#split the data into train and test sets
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.55, random_state=42)
#build the model
model = LinearRegression()
#fit the model
model.fit(xtrain, ytrain)
#Predicting the prices
pred = model.predict(xtest)
#look at the top 5 predictions vs top 5 real
print(pred[:5])
print(ytest[:5])
#appy mean absolute error
mean_absolute_error(y_true=ytest, y_pred=model.predict(xtest))
# Out:
# [209087.34061326 136908.39742271 157336.41775501 156842.06519348
#   44816.15980075]
# 123     181000
# 1191    112000
# 462     148000
# 351     134000
# 1296     82500
# Name: SalePrice, dtype: int64
# 26749.670558614504
