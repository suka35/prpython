# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
from skimage.feature import match_template

# %%
image = data.coins()

# %%
plt.imshow(image, cmap='gray')

# %%
coin = image[170:220, 75:130]

# %%
plt.imshow(coin, cmap='gray')

# %%
result = match_template(image, coin)

# %%
result
# Out:
# array([[-0.24104032, -0.23234978, -0.22480951, ...,  0.13229232,
#          0.12066407,  0.10665499],
#        [-0.22278403, -0.21381343, -0.20873436, ...,  0.14320038,
#          0.1268553 ,  0.11039347],
#        [-0.20515271, -0.19868663, -0.19270631, ...,  0.15875838,
#          0.13987642,  0.11784952],
#        ...,
#        [ 0.12420449,  0.1335519 ,  0.14105369, ...,  0.35121011,
#          0.37697757,  0.40005323],
#        [ 0.11772942,  0.12724731,  0.14093161, ...,  0.31126575,
#          0.33616605,  0.3600436 ],
#        [ 0.10770604,  0.11267493,  0.12733897, ...,  0.27736657,
#          0.30089005,  0.3245446 ]])

# %%
plt.imshow(result)

# %%
ij = np.unravel_index(np.argmax(result), result.shape)

# %%
ij
# Out:
# (170, 75)

# %%
x, y =ij[::-1]

# %%
x
# Out:
# 75

# %%
y
# Out:
# 170

# %%
hcoin, wcoin = coin.shape

# %%
fig, ax = plt.subplots()
ax.imshow(image,cmap='gray')
rect = plt.Rectangle((x,y), wcoin, hcoin, edgecolor='r', facecolor='none' )
ax.add_patch(rect)
